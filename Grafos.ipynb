# %%
GC = nx.complete_graph(7)
nx.draw_networkx(GC, node_color='g', node_size = 250 )

# %%
GL = nx.path_graph(4)
nx.draw_networkx(GL, node_color = 'g', node_size = 250)

# %%
GCi = nx.cycle_graph(8)
nx.draw_networkx(GCi, node_color = 'g', node_size = 250)

# %%
GV = nx.empty_graph(7)
nx.draw_networkx(GV, node_color='g', node_size=250)

# %%
GR = nx.hypercube_graph(3)
nx.draw_networkx(GR, node_color='g', node_size=250)

# %%
GT = nx.tetrahedral_graph()
nx.draw_networkx(GT, node_color= "g",node_size=250)

# %%
GCube = nx.cubical_graph()
nx.draw_networkx(GCube, node_color='g', node_size = 250)

# %%
GO = nx.octahedral_graph()
nx.draw_networkx(GO, node_color='g',node_size=250)

# %%
GD = nx.dodecahedral_graph()
nx.draw_networkx(GD, node_color='g', node_size=250)

# %%
GI = nx.icosahedral_graph()
nx.draw_networkx(GI, node_color='g',node_size=250)
